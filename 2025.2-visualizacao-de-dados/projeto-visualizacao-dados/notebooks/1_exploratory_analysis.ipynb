# %% [markdown]
# Este notebook tem como objetivo realizar uma análise exploratória inicial do conjunto de dados utilizando a biblioteca ydata_profiling, a fim de entender melhor as variáveis disponíveis, detectar possíveis problemas como valores ausentes e identificar padrões iniciais.

# %%
# Importando bibliotecas
import pandas as pd
from ydata_profiling import ProfileReport

# Carregando o conjunto de dados
df = pd.read_csv("../data/raw/SalesDataset.csv")

# Gerando o relatório exploratório
profile = ProfileReport(df, title="Relatório de Análise Exploratória")

# Visualizando no notebook
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-05-30 11:19:45.136145&quot;&gt;&lt;title&gt;Relatório de Análise Exploratória&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
